# %%
#Problem 2
x = 3
y = 4
x = x ^ y
y = x ^ y
x = x ^ y
print(x, y)
# Out:
# 4 3

# %%
#Problem 3
n = int(input())
if n & n - 1 == 0:
    print(f"{n} la mot luy thua cua 2")
else:
    print(f"{n} khong phai la mot ly thua cua 2")

# %%
#Problem 4
m, n = map(int, input().split())
print(f"Ket qua cua phep chia {m} cho {n} (duoc lam tron xuong la): {m//n}")
# Out:
#  9 4
# Ket qua cua phep chia 9 cho 4 (duoc lam tron xuong la): 2

# %%
#Problem 5
m, n = map(int, input().split())
print(f"Ket qua cua phep chia {m} cho {n} (duoc lam tron len la): {m//n + 1}")
# Out:
#  9 4
# Ket qua cua phep chia 9 cho 4 (duoc lam tron len la): 3

# %%
#Problem 6
x = int(input())
if x % 2 == 0:
    print("Even")
else: 
    print("Odd")
# Out:
#  7
# Odd

# %%
#Problem 7
a, b = map(int, input().split())
if a < 0 and b < 0:
    print("Yes")
else:
    print("No")
# Out:
#  -6 -6
# Yes

# %%
#Problem 8
a, b = map(str, input().split())
if len(a) > len(b):
    print("True")
else:
    print("False")
# Out:
#  iufghur gergie
# True

# %%
#Problem 9
a, b, c = map(int, input().split())
if a + b > c and b + c > a and c + a > b:
    print("Day la ba canh cua tam giac")
else:
    print("Day khong phai la ba canh cua tam giac")

# %%
#Problem 10
a, b, c, d = map(int, input().split())
if (a >= b) and (a >= c ) and (a >= d):
    print(a)
elif (b >= a) and (b >= c ) and (b >= d):
    print(b)
elif (c >= a) and (c >= a) and (c >= d):
    print(c)
else:
    print(d)

# %%
#Problem 11
a, b, c = map(int, input().split())
if a + b > c and b + c > a and c + a > b:
    print("Day la ba canh cua tam giac")
    if a*a + b*b == c*c or b*b + c*c == a*a or c*c + a*a == b*b:
        print("Day la tam giac vuong")
    elif a == b or b == c or c == a:
        print("Day la tam giac can")
    elif a == b == c:
        print("Day la tam giac deu")
    else:
        print("Day la tam giac thuong")
else:
    print("Day khong phai la ba canh cua tam giac")
# Out:
#  5 6 7
# Day la ba canh cua tam giac
# Day la tam giac thuong

# %%
#Problem 12
n = int(input())
if (n % 4 == 0 and n % 100 != 0) or n % 400 == 0:
    print("Day la nam nhuan")
else:
    print("Day khong phai nam nhuan")

# %%
#Problem 14
a, b = map(int, input().split())
if a == 0 and b == 0:
    print("Vo so nghiem")
elif a == 0 and b != 0:
    print("Vo nghiem")
else:
    print(f"Nghiem cua phuong trinh la: x = {-b/a:.2f}")
# Out:
#  0 0
# Vo so nghiem

# %%
#Problem 15
a = int(input())
if a >= 8:
    print("Gioi")
elif a >= 6.5:
    print("Kha")
elif a >= 5:
    print("Trung binh")
else:
    print("Yeu")
# Out:
#  5
# Trung binh

# %%
#Problem 16
x = float(input())
if int(x) == x:
    print(f"{x:.0f} lam tron la {x:.0f}")
else:
    print(f"{x} lam tron len la {int(x) + 1}, {x} lam tron xuong la {int(x)}")
# Out:
#  5
# 5 lam tron la 5

# %%
#Problem 17
a, b, c, d = map(int, input().split())
if 2*b == a + c and 2*c == b + d:
   print("Day la mot cap so cong")
else: 
   print("Day khong phai mot cap so cong")
# Out:
#  5 5 4 2
# Day khong phai mot cap so cong
