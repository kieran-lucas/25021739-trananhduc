# %%
print('hello')
# Out:
# hello

# %%
a = 7
b = 5
c = a - b
print(type(a), c, sep = '===', end = '\t')
print(a)
# Out:
# <class 'int'>===2	7

# %%
#W1A1 [User Input]
city = "Ha noi"
year = 2025
print("Thanh pho", city, "_ Nam", year)
print(type(city))
print(type(9.7))
# Out:
# Thanh pho Ha noi _ Nam 2025
# <class 'str'>
# <class 'float'>

# %%
# W1A3
n = 4
t = 0
for i in range(1, n+1):
    t += i
    print (t)
# Out:
# 1
# 3
# 6
# 10

# %%
#W1A4 
#Explain by ChatGPT:
numbers = [1, 2, 3, 4]   # you wrote numer → should be numbers

for x in numbers:        # loop through each element in the list
    if x % 2 == 0:       # check if x is divisible by 2
        print(x, "is even number")
    else:                # otherwise (if not divisible by 2)
        print(x, "is odd number")
#My attempt:
numbers = [1,2,3,4]
for x in numbers:
    if x % 2 == 0:
        print(x,"is even number")
    else:
        print(x, "is odd number")
# Out:
# 1 is odd number
# 2 is even number
# 3 is odd number
# 4 is even number
# 1 is odd number
# 2 is even number
# 3 is odd number
# 4 is even number

# %%
#W1A5
#Expain by ChatGPT:
# Create a list named animals with 4 elements
animals = ["cat", "dog", "cat", "bird"]

# Initialize a counter variable to 0
count = 0

# Loop through each element in the list
for a in animals:
    # For every element found, add 1 to the counter
    count += 1

# After the loop ends, print the total number of elements
print("Number of elements in the list:", count)
#my attempt:
animals = ["cat", "dog", "cat", "bird"]
count = 0 
for a in animals:
    count += 1
print("Number of elements in the list:", count)
# Out:
# Number of elements in the list: 4
# Number of elements in the list: 4

# %%
#W1A6
#Explain by ChatGPT

# Print the program title (shows the menu header)
print("=== AI Prediction System ===")

# Print option 1: Sentiment analysis
print("1) Sentiment analysis")

# Print option 2: Weather forecast
print("2) Weather forecast")

# Print option 3: Exit
print("3) Exit")

# Ask the user to type their choice; input() returns a string
choice = input("Please choose an option: ")

# Decide what to do based on the user's input
if choice == "1":
    # If the user types "1", run (or call) the sentiment-analysis functionality
    print("You chose: Sentiment analysis")
elif choice == "2":
    # If the user types "2", run (or call) the weather-forecast functionality
    print("You chose: Weather forecast")
elif choice == "3":
    # If the user types "3", exit the program (or end the loop)
    print("Exiting program. Goodbye!")
else:
    # If the input is not "1", "2", or "3", inform the user it's invalid
    print("Invalid choice — please enter 1, 2, or 3.")

# %%
#W1A7
#My attempt:
num = input("Add number: ") #this statement returns a string type, so it must convert in to int
if num % 2 = 0:
print("Even number") #missing indentation
else #missing colon
print("Odd number") #missingn indentation

# %%
#WA18
#Explain by ChatGPT:
# Repeat a block of code 3 times
for i in range(3):
    # Print the message and the current iteration number (i+1 makes it start from 1 instead of 0)
    print("AI is reading time", i + 1)

# After the loop finishes, print this message once
print("Training completed!")

# %%
##W1A9
#Expain by ChatGPT:
# Repeat a block of code 3 times using a for loop
for i in range(3):
    # On each loop, print the message and the current value of i
    print("Predict the animal:", i)

# %%
#W1A10
#Simple nemu
print "=== AI Prediction System ==="
print("1) Sentiment analysis"
print('3) Exit'
print("Plase choose an option.")
#Explain error by Chat GPT:
      # Original with inline notes (errors explained)

# Simple nemu
# ^ typo in the comment: "nemu" -> "menu" (only cosmetic)

print "=== AI Prediction System ==="  
# ERROR: In Python 3 this is a SyntaxError — print must be called as a function: print(...).
#        (This line would be valid in Python 2, but Python 2 is obsolete. Use Python 3 syntax.)

print("1) Sentiment analysis"
# ERROR: Missing closing parenthesis ')' at the end of this line → SyntaxError.

print('3) Exit'
# ERROR: Missing closing parenthesis ')' here as well → SyntaxError.

print("Plase choose an option.")
# Small typo in the string: "Plase" -> "Please" (cosmetic, doesn't cause a crash)

# %%
#W2A2
'''
a = input()
a = input()
c = a + b
print (c)
'''
so1, so2 = map(int, input().split())
tong = so1 + so2
print(tong)

# %%
#W2A3
a,b = map(int, input().split())
print(f'{a} + {b} = {a+b}')
print(f'{a} - {b} = {a-b}')
print(f'{a} * {b} =  {a*b}')
print(f'{a} // {b} = {a//b:.2f}')
print(f'{a} % {b} = {a%b}')

# %%
#W2A4
a1, b1, c1, a2, b2, a3 = map(int, input().split())
tb = ((a1+b1+c1)+(a2+b2)*2+a3*3)/10
print(f'{tb:.1f}')

# %%
#W2A5
a, b = map(int, input().split())
t=a**b
print(f'{t}')

# %%
#W2A6
a = input()
print(a.upper())
s2 = input()
s2 = ord(s2) - 32
s2 = chr(s2)
print(s2)

# %%
#W2A7
A = ((13 ** 2) * 3) + 5
B = 13**2*3 + 5
print(A)
print(B)

# %%
#W2A8
c = float(input())
f = 9/5*c + 32
print(f'{f:.2f}')

# %%
#W2A9
x = int(input())
x = 10 + 0.3*x + 0.1*x
print(f'{x:.2f}')

# %%
#W2A10
a, b, c= map(str, input().split())
print(c,b,a)
