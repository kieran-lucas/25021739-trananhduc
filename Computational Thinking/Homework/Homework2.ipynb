# %%
#Problem1
a, b = map(int, input().split())
print(f"Dien tich hinh chu nhat: {a*b}")
print(f"Chu vi hinh chu nhat: {2*(a+b)}")
# Out:
#  6 7
# Dien tich hinh chu nhat: 42
# Chu vi hinh chu nhat: 26

# %%
#Problem 2
r = int(input())
print(f"Dien tich hinh tron: {3.14*r*r:.2f}")
print(f"Chu vi hinh tron: {2*3.14*r:.2f}")

# %%
#Problem 3
a, b, c = map(int, input().split())
if a + b > c and b + c > a and c + a > b:
    if a*a + b*b == c*c or b*b + c*c == a*a or c*c + a*a == b*b:
       print("Day la tam giac vuong")
    elif a == b == c:
       print("Day la tam giac deu")
    elif (a == b and a != c) or (a == c and a != b) or (b == c and b != a):
       print("Day la tam giac can")
    else:
       print("Day la tam giac thuong")
p = (a + b + c)/2
print(f"Dien tich cua tam giac la: {(p*(p-a)*(p-b)*(p-c))**(1/2):.2f}")
print(f"Chu vi cua tam giac la: {a + b + c:.2f}")
# Out:
#  5 6 5
# Day la tam giac can
# Dien tich cua tam giac la: 12.00
# Chu vi cua tam giac la: 16.00

# %%
#Problem 4
a, b = map(int, input().split())
x = -b/a
print(f"Nghiem cua phuong trinh {a}x + {b} = 0 la: {x:.2f}")
# Out:
#  5 6
# Nghiem cua phuong trinh 5x + 6 = 0 la: -1.20

# %%
#Problem 5
a, b, c = map(int, input().split())
d = b**2 - 4*a*c
if d < 0:
    print("Phuong trinh vo nghiem")
else:
    print(f"Phuong trinh co nghiem la {(-b + d**(1/2))/(2*a):.2f} va {(-b - d**(1/2))/(2*a):.2f}")
# Out:
#  5 6 1
# Phuong trinh co nghiem la -0.20 va -1.00

# %%
#Problem 6
a, b, c, d = map(int, input().split())
if (a >= b) and (a >= c ) and (a >= d):
    print(a)
elif (b >= a) and (b >= c ) and (b >= d):
    print(b)
elif (c >= a) and (c >= a) and (c >= d):
    print(c)
else:
    print(d)
# Out:
#  5 6 5 4
# 6

# %%
#Problem 7
a, b, c, d = map(int, input().split())
if (a <= b) and (a <= c ) and (a <= d):
    print(a)
elif (b <= a) and (b <= c ) and (b <= d):
    print(b)
elif (c <= a) and (c <= a) and (c <= d):
    print(c)
else:
    print(d)
# Out:
#  5 4 3 5
# 3

# %%
#Problem 8
a, b, c, d, m, n = map(int, input().split())
print(f'Nghiem cua he phuong trinh')
print(f'{a}x + {b}y = {m}')
print(f'{c}x + {d}y = {n}')
print("la: ")
print(f'x = {m/a-(b/a)*((n*a - m*c)/(d*a - b*c)):.2f}')
print(f'y = {(n*a - m*c)/(d*a - b*c):.2f}')
# Out:
#  5 6 3 6 5 5
# Nghiem cua he phuong trinh
# 5x + 6y = 5
# 3x + 6y = 5
# la:
# x = 0.00
# y = 0.83

# %%
#Problem 9
print("Nhap thoi gian hoan thanh cong viec")
x = int(input())
a = x//3600
b = x//60
if b < 1:
    print(f"Thoi gian hoan thanh cong viec la {x} giay")
elif b >= 1 and a < 1:
    print(f"Thoi gian hoan thanh cong viec la {b} phut {x - b*60} giay")
else:
    print(f"Thoi gian hoan thanh cong viec la {a} gio {b - a*60} phut {x - b*60} giay")
# Out:
# Nhap thoi gian hoan thanh cong viec
#  366
# Thoi gian hoan thanh cong viec la 6 phut 6 giay

# %%
#Problem 10
print("Nhap tam va ban kinh")
a, b = map(int, input().split())
r = int(input())
print("Nhap diem A")
x, y = map(int, input().split())
if (x - a)**2 + (y - b)**2 == r**2:
    print("Diem nay thuoc duong tron")
else:
    print("Diem nay khong thuoc duong tron")
# Out:
# Nhap tam va ban kinh
#  1 1
#  0
# Nhap diem A
#  1 1
# Diem nay thuoc duong tron

# %%
#Problem 11
